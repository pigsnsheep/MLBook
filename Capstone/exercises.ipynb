# %%
import pandas as pd

# %%
ds = pd.read_csv("megaGymDataset.csv")

# %%
ds.loc[(ds['BodyPart'] == 'Lower Back') & (ds['Equipment'] == 'Body Only') & (ds['Desc'].notnull()) & (ds['Rating'] >= 8)]
# Out:
#       Unnamed: 0           Title  \
# 1593        1593  Back extension
# 1595        1595        Superman
#
#                                                    Desc        Type  \
# 1593  The back extension is an exercise used to buil...    Strength
# 1595  The Superman is a bodyweight exercise that con...  Stretching
#
#         BodyPart  Equipment         Level  Rating RatingDesc
# 1593  Lower Back  Body Only  Intermediate     9.1    Average
# 1595  Lower Back  Body Only  Intermediate     8.3    Average

# %%
ds.loc[(ds['BodyPart'] == 'Lower Back') & (ds['Equipment'] == 'Body Only') & (ds['Desc'].notnull()) & (ds['Rating'] >= 8)]

# %%
ds[ds['Equipment'] == 'Barbell']
# Out:
#       Unnamed: 0                                              Title  \
# 8              8                                   Barbell roll-out
# 9              9                      Barbell Ab Rollout - On Knees
# 10            10                           Decline bar press sit-up
# 11            11                             Bench barbell roll-out
# 12            12                                  Barbell Side Bend
# ...          ...                                                ...
# 2785        2785                           Reverse Band Bench Press
# 2786        2786  Decline Barbell Triceps Extension - Gethin Var...
# 2787        2787                                    AM Skullcrusher
# 2788        2788                     30 Arms Close-Grip Bench Press
# 2789        2789                       30 Arms Barbell Skullcrusher
#
#                                                    Desc          Type  \
# 8     The barbell roll-out is an abdominal exercise ...      Strength
# ...

# %%
# import module
import pandas as pd
 
# assign data
dataFrame = pd.DataFrame({'Name': [' RACHEL  ', ' MONICA  ', ' PHOEBE  ',
                                   '  ROSS    ', 'CHANDLER', ' JOEY    '],
                           
                          'Age': [30, 35, 37, 33, 34, 30],
                           
                          'Salary': [100000, 93000, 88000, 120000, 94000, 95000],
                           
                          'JOB': ['DESIGNER', 'CHEF', 'MASUS', 'PALENTOLOGY',
                                  'IT', 'ARTIST']})
# filter dataframe
dataFrame[(dataFrame['Salary']>=100000) & (dataFrame['Age']< 40) & (dataFrame['JOB'].str.startswith('D'))]
# Out:
#         Name  Age  Salary       JOB
# 0   RACHEL     30  100000  DESIGNER
